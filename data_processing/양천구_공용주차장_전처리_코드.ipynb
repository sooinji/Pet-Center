# %%
import pandas as pd
import numpy as np
from plotnine import *
import missingno as msno
import matplotlib.pyplot as plt

#한글 출력
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (10.2 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
plt.rcParams['font.family']='NanumBarunGothic' #나눔바른고딕 적용하기

# %% [markdown]
# # 양천구 공영주차장

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cf72fd20-3df4-4b81-ba7a-05d91844f0eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf72fd20-3df4-4b81-ba7a-05d91844f0eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_parking_yangcheon_data = pd.read_csv('서울시 공영주차장 안내 정보.csv', encoding="CP949")
df_parking_yangcheon_data
# Out:
#        주차장코드              주차장명              주소 주차장 종류 주차장 종류명  운영구분    운영구분명  \
# 0    1037569        바람개비주차장(구)    양천구 목동 919-8     NW  노외 주차장     1  시간제 주차장
# 1    1367218         한마음주차장(구)    양천구 목동 914-5     NW  노외 주차장     1  시간제 주차장
# 2    1371689     양천사회단체봉사센터(구)   양천구 목동 905-29     NW  노외 주차장     1  시간제 주차장
# 3    1371690          목동타운홀(구)   양천구 목동 905-21     NW  노외 주차장     1  시간제 주차장
# 4     144561           한국통신(구)    양천구 목동 924-1     NS  노상 주차장     1  시간제 주차장
# ..       ...               ...             ...    ...     ...   ...      ...
# 912  3119519      한마음 공영주차장(구)    양천구 목동 914-5     NW  노외 주차장     1  시간제 주차장
# 913  3133323  문화회관 동측 공영주차장(구)   양천구 신정동 322-5     NW  노외 주차장     1  시간제 주차장
# 914  3154932       누리 공영주차장(구)  양천구 신정동 323-13     NW  노외 주차장     1  시간제 주차장
# 915  3156969      어울림 공영주차장(구)   양천구 신정동 318-2     NW  노외 주차장     1  시간제 주차장
# 916   881056     목동노외 공영주차장(시)   양천구 목동 905-32     NW  노외 주차장     1  시간제 주차장
#
# ...

# %%
df_parking_yangcheon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917 entries, 0 to 916
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   주차장코드              917 non-null    int64
#  1   주차장명               917 non-null    object
#  2   주소                 917 non-null    object
#  3   주차장 종류             917 non-null    object
#  4   주차장 종류명            917 non-null    object
#  5   운영구분               917 non-null    int64
#  6   운영구분명              917 non-null    object
#  7   전화번호               732 non-null    object
#  8   주차현황 정보 제공여부       917 non-null    int64
#  9   주차현황 정보 제공여부명      917 non-null    object
#  10  총 주자면              917 non-null    int64
#  11  유무료구분              917 non-null    object
#  12  유무료구분명             917 non-null    object
#  13  야간무료개방여부           917 non-null    object
#  14  야간무료개방여부명          917 non-null    object
#  15  평일 운영 시작시각(HHMM)   917 non-null    int64
# ...

# %%
df_parking_yangcheon = df_parking_yangcheon_data.reset_index(drop=True).drop(columns=['주차장코드', '주차장 종류', '주차장 종류명','운영구분', '운영구분명','전화번호', '주차현황 정보 제공여부', '주차현황 정보 제공여부명', '총 주자면', '유무료구분', '유무료구분명', '야간무료개방여부', '야간무료개방여부명', '평일 운영 시작시각(HHMM)', '평일 운영 종료시각(HHMM)', '주말 운영 시작시각(HHMM)', '주말 운영 종료시각(HHMM)', '공휴일 운영 시작시각(HHMM)', '공휴일 운영 종료시각(HHMM)', '최종데이터 동기화 시간', '토요일 유,무료 구분', '토요일 유,무료 구분명', '공휴일 유,무료 구분', '공휴일 유,무료 구분명', '월 정기권 금액', '노상 주차장 관리그룹번호', '버스 기본 주차 요금', '버스 기본 주차 시간(분 단위)', '버스 추가 단위 시간(분 단위)', '일 최대 요금'])
df_parking_yangcheon
# Out:
#                  주차장명              주소  기본 주차 요금  기본 주차 시간(분 단위)  추가 단위 요금  \
# 0          바람개비주차장(구)    양천구 목동 919-8       150               5     150.0
# 1           한마음주차장(구)    양천구 목동 914-5       150               5     150.0
# 2       양천사회단체봉사센터(구)   양천구 목동 905-29       150               5     150.0
# 3            목동타운홀(구)   양천구 목동 905-21       150               5     150.0
# 4             한국통신(구)    양천구 목동 924-1       250               5     250.0
# ..                ...             ...       ...             ...       ...
# 912      한마음 공영주차장(구)    양천구 목동 914-5       150               5       NaN
# 913  문화회관 동측 공영주차장(구)   양천구 신정동 322-5       150               5       NaN
# 914       누리 공영주차장(구)  양천구 신정동 323-13       150               5       NaN
# 915      어울림 공영주차장(구)   양천구 신정동 318-2       150               5       0.0
# 916     목동노외 공영주차장(시)   양천구 목동 905-32       150               5     150.0
#
#      추가 단위 시간(분 단위)  버스 추가 단위 요금         위도          경도
# ...

# %%
df_parking_yc = df_parking_yangcheon.drop_duplicates(subset="주차장명")
df_parking_yc
# Out:
#                  주차장명             주소  기본 주차 요금  기본 주차 시간(분 단위)  추가 단위 요금  \
# 0          바람개비주차장(구)   양천구 목동 919-8       150               5     150.0
# 1           한마음주차장(구)   양천구 목동 914-5       150               5     150.0
# 2       양천사회단체봉사센터(구)  양천구 목동 905-29       150               5     150.0
# 3            목동타운홀(구)  양천구 목동 905-21       150               5     150.0
# 4             한국통신(구)   양천구 목동 924-1       250               5     250.0
# ..                ...            ...       ...             ...       ...
# 910     바람개비 공영주차장(구)   양천구 목동 919-8       150               5       NaN
# 912      한마음 공영주차장(구)   양천구 목동 914-5       150               5       NaN
# 913  문화회관 동측 공영주차장(구)  양천구 신정동 322-5       150               5       NaN
# 915      어울림 공영주차장(구)  양천구 신정동 318-2       150               5       0.0
# 916     목동노외 공영주차장(시)  양천구 목동 905-32       150               5     150.0
#
#      추가 단위 시간(분 단위)  버스 추가 단위 요금         위도          경도
# ...

# %%
df_parking_yc.to_csv('양천구 공영주차장.csv', index=False)
